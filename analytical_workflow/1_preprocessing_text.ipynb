# %%
import pandas as pd

# Membaca file Excel menggunakan pandas
nama_file = "Data Mentah.csv"  # Ganti dengan nama file yang sesuai
Data = pd.read_csv(nama_file, encoding='ISO-8859-1')

# Menampilkan beberapa baris pertama dari dataframe
Data.head(15000)
# Out:
#                  ID                 Date       Username         Display Name  \
# 0      1.740520e+18  2023-12-28 23:59:44    sujiwo_tego  haha hihi huhu heha
# 1      1.740520e+18  2023-12-28 23:59:44       SKoncoro      Koncoro pranoto
# 2      1.740520e+18  2023-12-28 23:59:24       okvin_mo      Maulindya Okvin
# 3      1.740520e+18  2023-12-28 23:59:15      kookissed  timmy the sheep ???
# 4      1.740520e+18  2023-12-28 23:59:12     guard00347        big frostivus
# ...             ...                  ...            ...                  ...
# 14130  1.739080e+18  2023-12-25 00:10:39        smpkcng                biasa
# 14131  1.739080e+18  2023-12-25 00:09:20  SonOfAdam1923          Son Of Adam
# 14132  1.739080e+18  2023-12-25 00:06:07        okino2x                pepso
# 14133  1.739070e+18  2023-12-25 00:04:44   antonyalim89                  Ton
# 14134  1.739070e+18  2023-12-25 00:03:55  Kopi_and_Chat        Jacks Hunters
#
#                                                  Content  \
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
#                                                      URL
# 0      https://twitter.com/sujiwo_tego/status/1740522...
# 1      https://twitter.com/SKoncoro/status/1740522953...
# 2      https://twitter.com/okvin_mo/status/1740522871...
# 3      https://twitter.com/kookissed/status/174052283...
# 4      https://twitter.com/guard00347/status/17405228...
# ...                                                  ...
# 14130  https://twitter.com/smpkcng/status/17390761512...
# 14131  https://twitter.com/SonOfAdam1923/status/17390...
# 14132  https://twitter.com/okino2x/status/17390750080...
# 14133  https://twitter.com/antonyalim89/status/173907...
# 14134  https://twitter.com/Kopi_and_Chat/status/17390...
#
# [14135 rows x 6 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14135 entries, 0 to 14134
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            14135 non-null  float64
#  1   Date          14135 non-null  object
#  2   Username      14135 non-null  object
#  3   Display Name  14133 non-null  object
#  4   Content       14135 non-null  object
#  5   URL           14135 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 662.7+ KB

# %%
#Tahap Awal Preprocessing
df = pd.DataFrame(Data['Content'])
df.head(15000)
# Out:
#                                                  Content
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
# [14135 rows x 1 columns]

# %%
#Case Folding
df['Case Folding'] = df['Content'].str.lower()
df.head(15000)
# Out:
#                                                  Content  \
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
#                                             Case Folding
# 0      @adriansyahyasin hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id rohingya itu cuma...
# 2      @ristarl @gojocatty @herricahyadi itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @y_d_y_p gw juga penasaran nih, di my...
# 14131  @kegblgnunfaedh suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh jejak digital ini tak bisa hil...
# 14133  @tanyakanrl twit2 palestine sekarang sepi pemi...
# 14134  @folkshittmedia nanti kalau meninggal datang t...
#
# [14135 rows x 2 columns]

# %%
#Cleaning
import re
import string
import nltk

def remove_URL(tweet): #Menghapus URL/Link
  url = re.compile(r'https?://\S+|www\.\S+')
  return url.sub(r'', tweet)

def remove_emoji(tweet): #Menghapus emoji
  emoji_pattern = re.compile("["
    u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U0001F1E0-\U0001F1FF"
    u"\U000024C2-\U0001F251"
    u"\U0001f926-\U0001f937"
    u"\U00010000-\U0010ffff"
    u"\u2600-\u2B55"
    u"\u200d"
    u"\u23cf"
    u"\u23e9"
    u"\u231a"
    u"\ufe0f"
    u"\u3030"
                        "]+", flags=re.UNICODE)
  return emoji_pattern.sub(r'', tweet)

def remove_angka_dll(tweet):
  tweet = re.sub(r'\d+', '', tweet) #Menghapus angka
  tweet = re.sub(r'\$\w*', '', tweet) #Menghapus ticker pasar saham seperti $GE
  tweet = re.sub(r'^RT[\s]+', '', tweet) #Menghapus RT
  tweet = re.sub(r'#[^\s]+', '', tweet) #Menghapus hashtag
  tweet = re.sub(r'@[^\s]+', '', tweet) #Menghapus mention
  tweet = re.sub(r'\n', ' ', tweet) #Menghapus hal baru
  tweet = re.sub(r'&amp', '', tweet) #Menghapus tanda &amp
  tweet = re.sub(r'[^A-Za-z ]+', ' ', tweet) #Menghapus karakter non alfabet
  tweet = tweet.strip()
  return tweet

df['Cleaning'] = df['Case Folding'].apply(lambda x: remove_URL(x))
df['Cleaning'] = df['Cleaning'].apply(lambda x: remove_emoji(x))
df['Cleaning'] = df['Cleaning'].apply(lambda x: remove_angka_dll(x))
df.head(15000)
# Out:
#                                                  Content  \
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
#                                             Case Folding  \
# 0      @adriansyahyasin hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id rohingya itu cuma...
# 2      @ristarl @gojocatty @herricahyadi itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @y_d_y_p gw juga penasaran nih, di my...
# 14131  @kegblgnunfaedh suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh jejak digital ini tak bisa hil...
# 14133  @tanyakanrl twit2 palestine sekarang sepi pemi...
# 14134  @folkshittmedia nanti kalau meninggal datang t...
#
#                                                 Cleaning
# 0      hei rohingya  ke sini aja  jakarta   pingin li...
# 1      rohingya itu cuman proyek  kalian paham kan pe...
# 2      itu bentuk kecewa tindak tegas  emang anak   w...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      gak yakin gw dengan mental org rohingya  merek...
# ...                                                  ...
# 14130  gw juga penasaran nih  di myanmar perang etnis...
# 14131                  suruh keja paksa aja tuh rohingya
# 14132  jejak digital ini tak bisa hilang  sekarang mu...
# 14133  twit palestine sekarang sepi peminat  giliran ...
# 14134  nanti kalau meninggal datang tuh cnn dan bbc a...
#
# [14135 rows x 3 columns]

# %%
#Normalisasi
kamus_df = pd.read_csv('Kamus Normalisasi Rohingya.csv')

# Fungsi untuk normalisasi teks berdasarkan kamus normalisasi
def normalisasi(str_text):
    for i in norm:
        if pd.notna(norm[i]):  # Memeriksa apakah nilai normalisasi tidak NaN
            str_text = str_text.replace(i, norm[i])
        else:
            str_text = str_text.replace(i, '')  # Menghapus kata asal jika normalisasi adalah NaN
    return str_text

# Membuat kamus normalisasi dari DataFrame kamus_df
norm = dict(zip(kamus_df['Kata Asal'], kamus_df['Kata Normalisasi']))

# Normalisasi kolom 'Cleaning' pada DataFrame 'df'
df['Normalization'] = df['Cleaning'].apply(normalisasi)
df.head(15000)
# Out:
#                                                  Content  \
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
#                                             Case Folding  \
# 0      @adriansyahyasin hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id rohingya itu cuma...
# 2      @ristarl @gojocatty @herricahyadi itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @y_d_y_p gw juga penasaran nih, di my...
# 14131  @kegblgnunfaedh suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh jejak digital ini tak bisa hil...
# 14133  @tanyakanrl twit2 palestine sekarang sepi pemi...
# 14134  @folkshittmedia nanti kalau meninggal datang t...
#
#                                                 Cleaning  \
# 0      hei rohingya  ke sini aja  jakarta   pingin li...
# 1      rohingya itu cuman proyek  kalian paham kan pe...
# 2      itu bentuk kecewa tindak tegas  emang anak   w...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      gak yakin gw dengan mental org rohingya  merek...
# ...                                                  ...
# 14130  gw juga penasaran nih  di myanmar perang etnis...
# 14131                  suruh keja paksa aja tuh rohingya
# 14132  jejak digital ini tak bisa hilang  sekarang mu...
# 14133  twit palestine sekarang sepi peminat  giliran ...
# 14134  nanti kalau meninggal datang tuh cnn dan bbc a...
#
#                                            Normalization
# 0      hei rohingya  ke sini saja  jakarta   ingin li...
# 1      rohingya itu hanya proyek  kalian paham permai...
# 2      itu bentuk kecewa tindak tegas  memang anak   ...
# 3      sadar kalian yang komen tanpa hati nurani di p...
# 4      gak yakin saya dengan mental orang rohingya  m...
# ...                                                  ...
# 14130  saya juga penasaran   di myanmar perang etnis ...
# 14131                   suruh kerja paksa saja  rohingya
# 14132  jejak digital ini tidak bisa hilang  sekarang ...
# 14133  postingan palestina sekarang sepi peminat  gil...
# 14134  nanti kalau meninggal datang  cnn dan bbc amer...
#
# [14135 rows x 4 columns]

# %%
#Tokenization
df['Tokenization'] = df['Normalization'].apply(lambda x:x.split())
df.head(15000)
# Out:
#                                                  Content  \
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
#                                             Case Folding  \
# 0      @adriansyahyasin hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id rohingya itu cuma...
# 2      @ristarl @gojocatty @herricahyadi itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @y_d_y_p gw juga penasaran nih, di my...
# 14131  @kegblgnunfaedh suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh jejak digital ini tak bisa hil...
# 14133  @tanyakanrl twit2 palestine sekarang sepi pemi...
# 14134  @folkshittmedia nanti kalau meninggal datang t...
#
#                                                 Cleaning  \
# 0      hei rohingya  ke sini aja  jakarta   pingin li...
# 1      rohingya itu cuman proyek  kalian paham kan pe...
# 2      itu bentuk kecewa tindak tegas  emang anak   w...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      gak yakin gw dengan mental org rohingya  merek...
# ...                                                  ...
# 14130  gw juga penasaran nih  di myanmar perang etnis...
# 14131                  suruh keja paksa aja tuh rohingya
# 14132  jejak digital ini tak bisa hilang  sekarang mu...
# 14133  twit palestine sekarang sepi peminat  giliran ...
# 14134  nanti kalau meninggal datang tuh cnn dan bbc a...
#
#                                            Normalization  \
# 0      hei rohingya  ke sini saja  jakarta   ingin li...
# 1      rohingya itu hanya proyek  kalian paham permai...
# 2      itu bentuk kecewa tindak tegas  memang anak   ...
# 3      sadar kalian yang komen tanpa hati nurani di p...
# 4      gak yakin saya dengan mental orang rohingya  m...
# ...                                                  ...
# 14130  saya juga penasaran   di myanmar perang etnis ...
# 14131                   suruh kerja paksa saja  rohingya
# 14132  jejak digital ini tidak bisa hilang  sekarang ...
# 14133  postingan palestina sekarang sepi peminat  gil...
# 14134  nanti kalau meninggal datang  cnn dan bbc amer...
#
#                                             Tokenization
# 0      [hei, rohingya, ke, sini, saja, jakarta, ingin...
# 1      [rohingya, itu, hanya, proyek, kalian, paham, ...
# 2      [itu, bentuk, kecewa, tindak, tegas, memang, a...
# 3      [sadar, kalian, yang, komen, tanpa, hati, nura...
# 4      [gak, yakin, saya, dengan, mental, orang, rohi...
# ...                                                  ...
# 14130  [saya, juga, penasaran, di, myanmar, perang, e...
# 14131              [suruh, kerja, paksa, saja, rohingya]
# 14132  [jejak, digital, ini, tidak, bisa, hilang, sek...
# 14133  [postingan, palestina, sekarang, sepi, peminat...
# 14134  [nanti, kalau, meninggal, datang, cnn, dan, bb...
#
# [14135 rows x 5 columns]

# %%
#Filtering/Stopword Removal
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# Ambil stopwords dalam bahasa Indonesia (atau sesuai kebutuhan)
stop_words = set(stopwords.words('indonesian'))
stop_words.remove('tidak')

# Proses filtering tanpa menghapus kata "tidak"
def remove_stopwords(text):
  return [word for word in text if word not in stop_words]

df['Filtering'] = df['Tokenization'].apply(lambda x: remove_stopwords(x))
df.head(15000)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                                  Content  \
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
#                                             Case Folding  \
# 0      @adriansyahyasin hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id rohingya itu cuma...
# 2      @ristarl @gojocatty @herricahyadi itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @y_d_y_p gw juga penasaran nih, di my...
# 14131  @kegblgnunfaedh suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh jejak digital ini tak bisa hil...
# 14133  @tanyakanrl twit2 palestine sekarang sepi pemi...
# 14134  @folkshittmedia nanti kalau meninggal datang t...
#
#                                                 Cleaning  \
# 0      hei rohingya  ke sini aja  jakarta   pingin li...
# 1      rohingya itu cuman proyek  kalian paham kan pe...
# 2      itu bentuk kecewa tindak tegas  emang anak   w...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      gak yakin gw dengan mental org rohingya  merek...
# ...                                                  ...
# 14130  gw juga penasaran nih  di myanmar perang etnis...
# 14131                  suruh keja paksa aja tuh rohingya
# 14132  jejak digital ini tak bisa hilang  sekarang mu...
# 14133  twit palestine sekarang sepi peminat  giliran ...
# 14134  nanti kalau meninggal datang tuh cnn dan bbc a...
#
#                                            Normalization  \
# 0      hei rohingya  ke sini saja  jakarta   ingin li...
# 1      rohingya itu hanya proyek  kalian paham permai...
# 2      itu bentuk kecewa tindak tegas  memang anak   ...
# 3      sadar kalian yang komen tanpa hati nurani di p...
# 4      gak yakin saya dengan mental orang rohingya  m...
# ...                                                  ...
# 14130  saya juga penasaran   di myanmar perang etnis ...
# 14131                   suruh kerja paksa saja  rohingya
# 14132  jejak digital ini tidak bisa hilang  sekarang ...
# 14133  postingan palestina sekarang sepi peminat  gil...
# 14134  nanti kalau meninggal datang  cnn dan bbc amer...
#
#                                             Tokenization  \
# 0      [hei, rohingya, ke, sini, saja, jakarta, ingin...
# 1      [rohingya, itu, hanya, proyek, kalian, paham, ...
# 2      [itu, bentuk, kecewa, tindak, tegas, memang, a...
# 3      [sadar, kalian, yang, komen, tanpa, hati, nura...
# 4      [gak, yakin, saya, dengan, mental, orang, rohi...
# ...                                                  ...
# 14130  [saya, juga, penasaran, di, myanmar, perang, e...
# 14131              [suruh, kerja, paksa, saja, rohingya]
# 14132  [jejak, digital, ini, tidak, bisa, hilang, sek...
# 14133  [postingan, palestina, sekarang, sepi, peminat...
# 14134  [nanti, kalau, meninggal, datang, cnn, dan, bb...
#
#                                                Filtering
# 0      [hei, rohingya, jakarta, lihat, respon, warga,...
# 1      [rohingya, proyek, paham, permainan, tidak, ta...
# 2      [bentuk, kecewa, tindak, anak, wanita, rohingy...
# 3      [sadar, komen, hati, nurani, postingan, rohingya]
# 4            [gak, mental, orang, rohingya, kenal, uang]
# ...                                                  ...
# 14130  [penasaran, myanmar, perang, etnis, negara, pe...
# 14131                    [suruh, kerja, paksa, rohingya]
# 14132  [jejak, digital, tidak, hilang, muslim, rohing...
# 14133  [postingan, palestina, sepi, peminat, giliran,...
# 14134  [meninggal, cnn, bbc, amerika, pernyataan, ind...
#
# [14135 rows x 6 columns]

# %%
#Steamming Data
# !pip install Sastrawi

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_text(text):
  return [stemmer.stem(word) for word in text]

df['Stemming'] = df['Filtering'].apply(lambda x: ' '.join(stem_text(x)))
df.head(15000)
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
#                                                  Content  \
# 0      @adriansyahyasin Hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id Rohingya itu cuma...
# 2      @RistaRL @gojocatty @herricahyadi Itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam Gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @Y_D_Y_P gw juga penasaran nih, di My...
# 14131  @kegblgnunfaedh Suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 14133  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 14134  @folkshittmedia Nanti kalau meninggal datang t...
#
#                                             Case Folding  \
# 0      @adriansyahyasin hei rohingya, ke sini aja... ...
# 1      @nionaalfaen @neohistoria_id rohingya itu cuma...
# 2      @ristarl @gojocatty @herricahyadi itu bentuk k...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      @gara_nam gak yakin gw dengan mental org2 rohi...
# ...                                                  ...
# 14130  @huntyng @y_d_y_p gw juga penasaran nih, di my...
# 14131  @kegblgnunfaedh suruh keja paksa aja tuh rohingya
# 14132  @kegblgnunfaedh jejak digital ini tak bisa hil...
# 14133  @tanyakanrl twit2 palestine sekarang sepi pemi...
# 14134  @folkshittmedia nanti kalau meninggal datang t...
#
#                                                 Cleaning  \
# 0      hei rohingya  ke sini aja  jakarta   pingin li...
# 1      rohingya itu cuman proyek  kalian paham kan pe...
# 2      itu bentuk kecewa tindak tegas  emang anak   w...
# 3      gewees buat kalian yang komen tanpa hati nuran...
# 4      gak yakin gw dengan mental org rohingya  merek...
# ...                                                  ...
# 14130  gw juga penasaran nih  di myanmar perang etnis...
# 14131                  suruh keja paksa aja tuh rohingya
# 14132  jejak digital ini tak bisa hilang  sekarang mu...
# 14133  twit palestine sekarang sepi peminat  giliran ...
# 14134  nanti kalau meninggal datang tuh cnn dan bbc a...
#
#                                            Normalization  \
# 0      hei rohingya  ke sini saja  jakarta   ingin li...
# 1      rohingya itu hanya proyek  kalian paham permai...
# 2      itu bentuk kecewa tindak tegas  memang anak   ...
# 3      sadar kalian yang komen tanpa hati nurani di p...
# 4      gak yakin saya dengan mental orang rohingya  m...
# ...                                                  ...
# 14130  saya juga penasaran   di myanmar perang etnis ...
# 14131                   suruh kerja paksa saja  rohingya
# 14132  jejak digital ini tidak bisa hilang  sekarang ...
# 14133  postingan palestina sekarang sepi peminat  gil...
# 14134  nanti kalau meninggal datang  cnn dan bbc amer...
#
#                                             Tokenization  \
# 0      [hei, rohingya, ke, sini, saja, jakarta, ingin...
# 1      [rohingya, itu, hanya, proyek, kalian, paham, ...
# 2      [itu, bentuk, kecewa, tindak, tegas, memang, a...
# 3      [sadar, kalian, yang, komen, tanpa, hati, nura...
# 4      [gak, yakin, saya, dengan, mental, orang, rohi...
# ...                                                  ...
# 14130  [saya, juga, penasaran, di, myanmar, perang, e...
# 14131              [suruh, kerja, paksa, saja, rohingya]
# 14132  [jejak, digital, ini, tidak, bisa, hilang, sek...
# 14133  [postingan, palestina, sekarang, sepi, peminat...
# 14134  [nanti, kalau, meninggal, datang, cnn, dan, bb...
#
#                                                Filtering  \
# 0      [hei, rohingya, jakarta, lihat, respon, warga,...
# 1      [rohingya, proyek, paham, permainan, tidak, ta...
# 2      [bentuk, kecewa, tindak, anak, wanita, rohingy...
# 3      [sadar, komen, hati, nurani, postingan, rohingya]
# 4            [gak, mental, orang, rohingya, kenal, uang]
# ...                                                  ...
# 14130  [penasaran, myanmar, perang, etnis, negara, pe...
# 14131                    [suruh, kerja, paksa, rohingya]
# 14132  [jejak, digital, tidak, hilang, muslim, rohing...
# 14133  [postingan, palestina, sepi, peminat, giliran,...
# 14134  [meninggal, cnn, bbc, amerika, pernyataan, ind...
#
#                                                 Stemming
# 0            hei rohingya jakarta lihat respon warga dki
# 1               rohingya proyek paham main tidak tampung
# 2      bentuk kecewa tindak anak wanita rohingya puku...
# 3             sadar komen hati nurani postingan rohingya
# 4                   gak mental orang rohingya kenal uang
# ...                                                  ...
# 14130  penasaran myanmar perang etnis negara berontak...
# 14131                         suruh kerja paksa rohingya
# 14132  jejak digital tidak hilang muslim rohingya dib...
# 14133  postingan palestina sepi minat gilir berita be...
# 14134  tinggal cnn bbc amerika nyata indonesia siksa ...
#
# [14135 rows x 7 columns]

# %%
#Simpan ke file CSV
df.to_csv('Rohingya Preprocessing.csv', encoding='utf8', index=False)
