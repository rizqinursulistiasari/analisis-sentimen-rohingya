# %%
import pandas as pd

# Membaca file Excel menggunakan pandas
nama_file = "tweets1k-1.xlsx"  # Ganti dengan nama file yang sesuai
Data = pd.read_excel(nama_file)

# Menampilkan beberapa baris pertama dari dataframe
Data.head(15000)
# Out:
#                        ID                Date         Username  \
# 0     1739433268192450048 2023-12-25 23:49:42  Putraaa34233363
# 1     1739432457911529984 2023-12-25 23:46:29          CikZieJ
# 2     1739121520516209920 2023-12-25 03:10:56      rafiziramli
# 3     1739431900224399872 2023-12-25 23:44:16      qitawan1234
# 4     1738543168562550016 2023-12-23 12:52:46       senzawakun
# ...                   ...                 ...              ...
# 1040  1739075008067150080 2023-12-25 00:06:07          okino2x
# 1041  1739074663551280128 2023-12-25 00:04:44     antonyalim89
# 1042  1739074455044009984 2023-12-25 00:03:55    Kopi_and_Chat
# 1043  1739073732466070016 2023-12-25 00:01:02       Abangleo69
# 1044  1739073576840689920 2023-12-25 00:00:25    shazlishah50x
#
#            Display Name                                            Content  \
# 0             Putraaaaa  @LokalPendaki pilihlah pemimpin yang menolak r...
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1045 non-null   int64
#  1   Date          1045 non-null   datetime64[ns]
#  2   Username      1045 non-null   object
#  3   Display Name  1044 non-null   object
#  4   Content       1045 non-null   object
#  5   URL           1045 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 49.1+ KB

# %%
#Menghapus data yang sama (duplikat )
Data.drop_duplicates(subset = "Content", keep = 'first', inplace = True)
Data.info(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1045 non-null   int64
#  1   Date          1045 non-null   datetime64[ns]
#  2   Username      1045 non-null   object
#  3   Display Name  1044 non-null   object
#  4   Content       1045 non-null   object
#  5   URL           1045 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 49.1+ KB

# %%
#Tahap Awal Preprocessing

df = pd.DataFrame(Data['Content'])
df.head(15000)
# Out:
#                                                 Content
# 0     @LokalPendaki pilihlah pemimpin yang menolak r...
# 1     Terima kasih yb rafizi atas penjelasan. Memang...
# 2     Pandangan saya mengenai pekerja asing:\n\n1) I...
# 3     Dgr tu org2 terpaling kemanusiaan.\n\nKorg byr...
# 4     suka cara doktor ni cakap tentang pendatang as...
# ...                                                 ...
# 1040  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 1041  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 1042  @folkshittmedia Nanti kalau meninggal datang t...
# 1043  @Bossbm17 @mynewshub Utk kerja Di kilang tidak...
# 1044  @kimtuwits @MALAYSIAVIRALLL dua pukimak. 1 tak...
#
# [1045 rows x 1 columns]

# %%
#Case Folding

df['Case Folding'] = df['Content'].str.lower()
df.head(15000)
# Out:
#                                                 Content  \
# 0     @LokalPendaki pilihlah pemimpin yang menolak r...
# 1     Terima kasih yb rafizi atas penjelasan. Memang...
# 2     Pandangan saya mengenai pekerja asing:\n\n1) I...
# 3     Dgr tu org2 terpaling kemanusiaan.\n\nKorg byr...
# 4     suka cara doktor ni cakap tentang pendatang as...
# ...                                                 ...
# 1040  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 1041  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 1042  @folkshittmedia Nanti kalau meninggal datang t...
# 1043  @Bossbm17 @mynewshub Utk kerja Di kilang tidak...
# 1044  @kimtuwits @MALAYSIAVIRALLL dua pukimak. 1 tak...
#
#                                            Case Folding
# 0     @lokalpendaki pilihlah pemimpin yang menolak r...
# 1     terima kasih yb rafizi atas penjelasan. memang...
# 2     pandangan saya mengenai pekerja asing:\n\n1) i...
# 3     dgr tu org2 terpaling kemanusiaan.\n\nkorg byr...
# ...

# %%
#Cleaning

import re
import string
import nltk

def remove_URL(tweet): #Menghapus URL/Link
  url = re.compile(r'https?://\S+|www\.\S+')
  return url.sub(r'', tweet)

def remove_emoji(tweet): #Menghapus emoji
  emoji_pattern = re.compile("["
    u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U0001F1E0-\U0001F1FF"
    u"\U000024C2-\U0001F251"
    u"\U0001f926-\U0001f937"
    u"\U00010000-\U0010ffff"
    u"\u2600-\u2B55"
    u"\u200d"
    u"\u23cf"
    u"\u23e9"
    u"\u231a"
    u"\ufe0f"
    u"\u3030"
                        "]+", flags=re.UNICODE)
  return emoji_pattern.sub(r'', tweet)

def remove_angka_dll(tweet):
  tweet = re.sub(r'\d+', '', tweet) #Menghapus angka
  tweet = re.sub(r'\$\w*', '', tweet) #Menghapus ticker pasar saham seperti $GE
  tweet = re.sub(r'^RT[\s]+', '', tweet) #Menghapus RT
  tweet = re.sub(r'#[^\s]+', '', tweet) #Menghapus hashtag
  tweet = re.sub(r'@[^\s]+', '', tweet) #Menghapus mention
  tweet = re.sub(r'\n', ' ', tweet) #Menghapus hal baru
  tweet = re.sub(r'&amp', '', tweet) #Menghapus tanda &amp
  #tweet = re.sub(r'\/', ' ', tweet) #Menghapus tanda / dan memberi spasi setelahnya
  tweet = re.sub(r'[^A-Za-z ]+', ' ', tweet) #Menghapus karakter non alfabet
  tweet = tweet.strip()
  return tweet

#def remove_simbol(tweet):
  #simbol = str.maketrans('', '', string.punctuation) #Menghapus tanda baca
  #return tweet.translate(simbol)

df['Cleaning'] = df['Case Folding'].apply(lambda x: remove_URL(x))
df['Cleaning'] = df['Cleaning'].apply(lambda x: remove_emoji(x))
df['Cleaning'] = df['Cleaning'].apply(lambda x: remove_angka_dll(x))

df.head(15000)
# Out:
#                                                 Content  \
# 0     @LokalPendaki pilihlah pemimpin yang menolak r...
# 1     Terima kasih yb rafizi atas penjelasan. Memang...
# 2     Pandangan saya mengenai pekerja asing:\n\n1) I...
# 3     Dgr tu org2 terpaling kemanusiaan.\n\nKorg byr...
# 4     suka cara doktor ni cakap tentang pendatang as...
# ...                                                 ...
# 1040  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 1041  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 1042  @folkshittmedia Nanti kalau meninggal datang t...
# 1043  @Bossbm17 @mynewshub Utk kerja Di kilang tidak...
# 1044  @kimtuwits @MALAYSIAVIRALLL dua pukimak. 1 tak...
#
#                                            Case Folding  \
# 0     @lokalpendaki pilihlah pemimpin yang menolak r...
# 1     terima kasih yb rafizi atas penjelasan. memang...
# 2     pandangan saya mengenai pekerja asing:\n\n1) i...
# 3     dgr tu org2 terpaling kemanusiaan.\n\nkorg byr...
# ...

# %%
import nltk
nltk.download('punkt')
from nltk import FreqDist
kalimat = ' '.join(df['Cleaning'])

tokens=nltk.tokenize.word_tokenize(kalimat)
kemunculan = nltk.FreqDist(tokens)
kemunculan.most_common(5000000)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('rohingya', 1133),
#  ('ni', 295),
#  ('di', 267),
#  ('yg', 258),
#  ('yang', 226),
#  ('tak', 221),
#  ('orang', 194),
#  ('ke', 191),
#  ('ada', 189),
#  ('tu', 183),
#  ('dia', 150),
#  ('dan', 147),
#  ('malaysia', 135),
#  ('pengungsi', 127),
#  ('nak', 124),
#  ('buat', 117),
#  ('ini', 113),
#  ('negara', 113),
#  ('dah', 112),
#  ('kita', 110),
#  ('indonesia', 108),
#  ('aku', 107),
#  ('mereka', 105),
#  ('la', 100),
#  ('tapi', 100),
#  ('sama', 99),
#  ('makan', 94),
#  ('pun', 94),
#  ('org', 87),
#  ('aja', 85),
#  ('apa', 84),
#  ('kalau', 83),
#  ('itu', 82),
#  ('kau', 82),
#  ('dari', 81),
#  ('dengan', 80),
#  ('aceh', 79),
#  ('jadi', 78),
#  ('warga', 78),
#  ('untuk', 75),
#  ('kat', 74),
#  ('dgn', 73),
#  ('macam', 73),
#  ('lagi', 69),
#  ('bukan', 68),
#  ('mcm', 66),
#  ('je', 62),
#  ('kena', 61),
#  ('pelarian', 61),
#  ('melayu', 61),
# ...

# %%
#Normalize

norm = {" ga ":" tidak ", "yg":"yang", "local":"lokal", "palestine":"palestina", "malaisya":"malaysia", "malay":"malaysia", "malaysiasia":"malaysia", "respond":"respon", " dgr ":" dengar ", "gewees buat":"sadar", "bikin":"buat", "emang ":"memang ", "mmemang":"memang", "mcm":" seperti ", "macam":"seperti", "cm":"cuma", " pki ":" ", "cuman":"hanya", "pinter":"pintar", " cuma ":" hanya ", "adlh":"adalah", "pingin":"ingin", "pengen":"ingin", "kemaren":"kemarin", "apus":"hapus", "hhapus":"hapus", "aje":"saja", "indo":"indonesia", "indonesianesia":"indonesia", "indonesian":"indonesia", " gk ":" tidak ", " aja ":" saja ", " ya ":" ", "prabowo":"",  " gak ":" tidak ", "km":"kamu", " lu ":" kamu ", "kalo":"kalau", " uda ":" sudah ", "udah":"sudah", "ssudah":"sudah", "msudah":"mudah", "yasudah":"ya sudah", "org":"orang", "orng":"orang", " ni ":" ", "anies":"", "abang":"", " nya ":" ", "malah":"justru", " tak ":" tidak ", " kan ":" ", " tu ":" ", " lah ":" ", " sih ":" ", "soal ":"tentang ", " si ":" ", "kok":"", "gw":"saya", "kau ":" kamu ", "ketpspilihnya":"", "ttp":"tetap", "tpi":"tapi", "tp":"tapi", "ktapi":"", " tuh":" ", " cut ":" ", "loe":"kamu", " lo ":" kamu ", "abu ":" ", "lahab":"", " dah ":" ", " pun ":" ", "liat":"lihat", "hoax":"berita bohong", "gini":"ini", "beini":"begini", "kayak":"seperti", "kaya":"seperti", "jgn":"jangan", "jga":"juga", "jg":"juga", " nak ":" ", "bgt":"banget", "gtu":"gitu", "gt":"gitu", "gitu":"itu", "beitu":"begitu", "gue":"saya", "sampe":"sampai", "gimana":"bagaimana", "biarin":"biarkan", " biar ":" agar ", "klo":"kalau", "ahok":"", "tiktok":"", "lee":"", "udh":"sudah", " bang ":" ", "bener":"benar", "bgt":"banget", "banget":"sekali", "jang ":" ", "nara ":" ", " kena ":" ", "sun kyun":"", "gua":"saya", "bapak":"", " pak ":" ", "kek":"seperti", "sepertierasan":"kekerasan", "sepertiecaewaan":"kekecewaan", "masbowogibran":"", "smakinmanteb":" ", "enggak":"tidak", " nggak ":"tidak", " ngga ":" tidak ", "engga":"tidak", "jdi":"jadi", "jd":"jadi", "tolol":"bodoh", "skrng":"sekarang", "krna":"karena", "krn":"karena", "nih":"", "sndri":"sendiri", "dri":"dari", "dr":"dari", "gerindaria":"", " la ":" ", " ngusir ":" usir ", "bakalan":"akan", "bakal":"akan", "pakek":"pakai", "pake":" pakai ", "they":"mereka", "the":"", "utk":"untuk", " nampung ":" menampung ", " kat ":" ", "aida":" ", "capres":"", "gemoy":"", " je ":" ", "facial wash":"", "mrka":"mereka", "mrk":"mereka", "deh":"", " pas ":" ", " x ":" ", "gibran":"", "tdk":"tidak", "emg":"memang", "duit":"uang", "doang":"saja", "ndasmu":"", "makin":"semakin", "sesemakin":"semakin", "menhan":"menteri pertahanan", "karna":"karena", "sosmed":"media sosial", "medsos":"media sosial", "smpe":"sampai", " sma ":" sama ", " sm ": " sama ", "diorang":"mereka", "mending":"lebih baik", " nolak ":" tolak ", "enembe":"", "lukas":"", "sok":"", "dgn":"dengan", "dg":"dengan", " ama ":" sama ", " in ":" ", " eh ":" ", "skrg":"sekarang", "kakak":"", "kak":"", " and ":" dan ", " to ":" ", " d ":" ", " palestin ":" palestina ", "dong":"", "mahfud":"", "loh":"", " ngungsi ":" mengungsi ", "goblok":"bodoh" , " kah ":" ", "wowo":"", "of":"", "ttg":"tentang", "koar":"protes", "sgakjaman":"", "blg":"bilang", "lg": "lagi", "soalnya":"karena", "paslon":"", "masbowogbran":"", " mah ":" ", "you":"kamu", "sebarkebencian":"sebar kebencian", " nah ":" ", " ko ":" ", "trus":"terus", " a ":" ", " g ":" tidak ", "mikir":"pikir", " t ":" ", "knp":"kenapa", "jokowi":"", " amin ":" ", "bencilihat":" benci lihat ", "subianto":"", "nerima":"terima", "meterima":"menerima", " ham ":" hak asasi manusia ", "rohingnya":"rohingya", " is ":" adalah ", "kampanyejahat":"kampanye jahat", "ganjar":"", "ngasih":"kasih", "tetep":"tetap", "bkn":"bukan", " ig ":" ", " an ":" ", "gatau":"tidak tahu", "dll":"", "zionist":"zionis", "dateng":"datang", "wk":"", "bacot":"omong kosong", "sdh":"sudah", " s ":" ", "timnas":"", " k ":" ", "supaya":"agar", "mmg":" memang ", "gmn":"bagaimana", "gimana":"bagaimana", " elu ":" kamu ", "anjing":"", " usah ":" perlu ", " so ":" ", " jubir ":" juru bicara ", " yaa ":" ", "mreka":"mereka", "bro":"", " al ":" ", " nk ":" ", "refugees":"pengungsi", " u ":" ", " klu ":" kalau ", " kl ":" kalau ", "gampang":"mudah", " cak ":" ", " mas ":" ", " bg ":" ", " bma ":" ", " sbb ":" ", " sosmed ":" media sosial ", " beneran ":" benar ", "pilpres":"", " min ":" ", "pulak":"juga", " pula ":" juga ", "bokep":"", " imin ":" ", " rame ":" ramai ", " dpt ":" dapat ", "dapet":"dapat", " ngurusin ":" mengurus ", " byk ":" banyak ", " no ":" ", " bego ":" bodoh ", " kt ":" kita ", " kyk ":" seperti ", "refugee":"pengungsi", " it ":" ", " w ":" ", " blm ":" belum ", " trs ":" terus ", " dlu ":" dulu ", " pd ":" pada ", " temen ":" teman ", " dtg ":" datang ", " baswedan ":" ", "kagak":"tidak", "kaga":"tidak", " sbg ":" sebagai ", " anjir ":" ", " yah ":" ", " pdhl ":" padahal ", " ngurus ":" urus ", "dlm ":"dalam ", " this ":" ", " dorang ":" mereka ", " kesel ":" kesal ", "kesal":"marah", " krna ":" karena ", " bangsat ":" ", " sy ":" saya ", " rohingiya ":" rohingya ", " oh ":" ", " spt ":" seperti ", " babi ":" ", " bangla ":" bangladesh ", " cek ":" ", " ngebela ":" bela ", " mu ":" ", " as ":" ", " ngerasain ":" merasakan ", " n ":" ", " gaada ":" tidak ada ", " diem ":" diam ", " tengok ":" lihat ", " up ":" ", " jdi ":" jadi ", " emng ":" memang ", " btw ":" ", " gabisa ":" tidak bisa ", " medsos ":" media sosial ", " gamau ":" tidak mau", " link ":" ", " ngerti ":" paham ", " kpd ":" kepada ", " tai ":" ", " rp ":" ", " they ":" mereka ", " bnyk ":" banyak ", " nanya ":" tanya ", " my ":" ", " abis ":" habis ", " dh ":" ", " noh ":" ", " on ":" ", " dikit ":" sedikit ", " ngaku ":" mengaku ", " ngak ":"tidak", " wong ":" ", "kontol":"", " but ":" tapi ", " bs ":" ", " for ":" untuk ", "muhaimin":"", "like":"", "vs":"", "bar bar":"kasar", "nyari":"cari", "jugak":"juga", "mbak":"", "ngatain":"mengatakan", " entah ":" tidak tahu ", " guys ":" ", " mesti ":" pasti ", " msh ":" masih ", " yaudah ":" ", " sender ":" ", " nder ":" ", " milih ":" pilih ", " md ":" ", " nyerang ":" serang ", " toh ":" ", " lho ":" ", " hrs ":" harus ", "kocak":"", "statement":"pernyataan", "israhell":"israel", "warlok":"warga lokal", "genocide":"genosida", "sgt":"sangat", "csis":"", " aku ":" saya ", " tni ":"", "ngapain":"untuk apa", "gara gara":"karena", " gara ":"karena", "cakap":"bicara", "banda":"", "tiap":"setiap", "sesetiap":"setiap", "pemilu":"", "lagian":"lagi pula", "benaran":"benar", "kebenar":"kebenaran", "mogok":"tidak", "belain":"bela", "jelek":"buruk", "nkri":"indonesia", "ngelunjak":"kurang ajar", "guna":"untuk", "menguntukkan":"menggunakan", "ngelihat":"melihat", "alias":"", "gada":"tidak ada", "takde":"tidak ada", "gausah":"tidak perlu", "faham":"paham", "dn":"dan", "giselle":"", "kasian":"kasihan", "kesian":"kasihan", "numpang":"menumpang", "nyebarin":"menyebarkan", "memenyebarkan":"menyebarkan", " nyebar ":" menyebar ", "pantes":"pantas", "mamah":"", "ngerasa":"merasa", "nyalahin":"menyalahkan", "mintak":"minta", "hantar":"antar", " all ":"", "tsb":"", "elok":"bagus", "dkt":"dekat", "jumpa":"bertemu", "thd":"terhadap", "banda":"", "waduh":"", " mba ":" ", " ntar ":" nanti ", "inget":"ingat", "ngomongin":"bicara", "ngomong":"bicara", "kemakan":"tertipu", "mcdonald":"", "dm":"pesan", " nuntut ":" menuntut ", "bawak":"bawa", " opa ":" ", "geng":"", "denger":"dengar", "lbh":"lebih", " bodo ":" bodoh ", "kesusahan":"kesulitan", "mulu":"terus", "terust":"mulut", "daripd":"daripada", "pastu":"setelah itu", "males":"malas", "sjw":"", "korang":"kalian", "bnyak":"banyak", " maksa ":" paksa ", "korlap":"", "pemda":"pemerintah daerah", " keja ":" kerja ", "pangandaran":"", "iya":"", "mirip":"seperti", " pbb ":" perserikatan bangsa bangsa ", "puak":"", "halau":"usir", "humanity":"kemanusiaan", "patut":"pantas", "unchr":"unhcr", "gede":"besar", "sidoarjo":"", "iskandar":"", "persis":"seperti", "sono":"sana", "awak":"kamu", "cawapres":"", "twit ":"tweet ", " yak ":" ", "nyampe":"sampai", "tweet":"postingan", "joget":"", " ikn ":" ", "sblm":"sebelum", " wni ":" pribumi ", "ngelakuin":"melakukan", "anis":"", "bicarain":"bicara", " ak ":" saya ", "gapapa":"tidak apa apa", "apbn":"", "pdip":"", "bbrp":"beberapa", "salahin":"salah", "nyamain":"menyamakan", "kemenkumham":"kementerian hukum dan hak asasi manusia", "walau":"walaupun", "walaupunpun":"walaupun", "jenayah":"", "thread":"", "jaman":"zaman", " tim ":" ", " tuan ":" ", "nyusahin":"menyusahkan", " anda ":" kamu ", "pesek":"", "menyuduntukan":"menyudutkan", " ndak ":" tidak ", "sbnr":"sebenar", "bnr":"benar", "sempet":"sempat", "gembel":"", " rb ":" ribu ", " jt ":" juta ", "antipalestina":"anti palestina", "antirohingya":"anti rohingya", "gaakan":"tidak akan", "smpk":"sampai", "smp":"sampai", "wow":"", "nambah ":"tambah ", "serem":"seram", "reels":"", "pln":"", " omong ":" bicara ", "thdp":"terhadap", " de ":" ", " agus ":" ", "berak":"", " ente ":" kamu ", "mika":"", "dsb":"", " naikin ":" menaikkan ", " tidu ":" ", "klean":"kalian", " ogah ":" tidak mau ", "gapunya":"tidak punya", "hehe":"", "choi taek":"", "arsenal":"", " fikir ":" pikir ", "xlayak":"tidak layak", "xde":"tidak ada"}
def normalisasi(str_text):
  for i in norm:
    str_text = str_text.replace(i, norm[i])
  return str_text

df['Normalization'] = df['Cleaning'].apply(lambda x: normalisasi(x))

df.head(15000)
# Out:
#                                                 Content  \
# 0     @LokalPendaki pilihlah pemimpin yang menolak r...
# 1     Terima kasih yb rafizi atas penjelasan. Memang...
# 2     Pandangan saya mengenai pekerja asing:\n\n1) I...
# 3     Dgr tu org2 terpaling kemanusiaan.\n\nKorg byr...
# 4     suka cara doktor ni cakap tentang pendatang as...
# ...                                                 ...
# 1040  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 1041  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 1042  @folkshittmedia Nanti kalau meninggal datang t...
# 1043  @Bossbm17 @mynewshub Utk kerja Di kilang tidak...
# 1044  @kimtuwits @MALAYSIAVIRALLL dua pukimak. 1 tak...
#
#                                            Case Folding  \
# 0     @lokalpendaki pilihlah pemimpin yang menolak r...
# 1     terima kasih yb rafizi atas penjelasan. memang...
# 2     pandangan saya mengenai pekerja asing:\n\n1) i...
# 3     dgr tu org2 terpaling kemanusiaan.\n\nkorg byr...
# ...

# %%
import nltk
nltk.download('punkt')
from nltk import FreqDist
kalimat = ' '.join(df['Normalization'])

tokens=nltk.tokenize.word_tokenize(kalimat)
kemunculan = nltk.FreqDist(tokens)
kemunculan.most_common(5000000)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('rohingya', 1138),
#  ('yang', 483),
#  ('tidak', 413),
#  ('orang', 281),
#  ('di', 269),
#  ('mereka', 224),
#  ('ada', 215),
#  ('seperti', 194),
#  ('ke', 191),
#  ('saya', 173),
#  ('dan', 172),
#  ('kamu', 163),
#  ('dengan', 154),
#  ('dia', 150),
#  ('kalau', 142),
#  ('pengungsi', 136),
#  ('tapi', 135),
#  ('malaysia', 135),
#  ('indonesia', 132),
#  ('untuk', 131),
#  ('kita', 129),
#  ('buat', 126),
#  ('juga', 124),
#  ('ini', 120),
#  ('itu', 119),
#  ('negara', 113),
#  ('palestina', 111),
#  ('saja', 109),
#  ('dari', 104),
#  ('jadi', 103),
#  ('sama', 103),
#  ('makan', 94),
#  ('apa', 89),
#  ('lagi', 88),
#  ('warga', 80),
#  ('memang', 79),
#  ('aceh', 79),
#  ('bukan', 70),
#  ('lebih', 65),
#  ('baik', 65),
#  ('pelarian', 61),
#  ('melayu', 61),
#  ('semua', 60),
#  ('sendiri', 59),
#  ('boleh', 57),
#  ('banyak', 57),
#  ('mana', 57),
# ...

# %%
#Tokenization

df['Tokenization'] = df['Normalization'].apply(lambda x:x.split())
df.head(15000)
# Out:
#                                                 Content  \
# 0     @LokalPendaki pilihlah pemimpin yang menolak r...
# 1     Terima kasih yb rafizi atas penjelasan. Memang...
# 2     Pandangan saya mengenai pekerja asing:\n\n1) I...
# 3     Dgr tu org2 terpaling kemanusiaan.\n\nKorg byr...
# 4     suka cara doktor ni cakap tentang pendatang as...
# ...                                                 ...
# 1040  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 1041  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 1042  @folkshittmedia Nanti kalau meninggal datang t...
# 1043  @Bossbm17 @mynewshub Utk kerja Di kilang tidak...
# 1044  @kimtuwits @MALAYSIAVIRALLL dua pukimak. 1 tak...
#
#                                            Case Folding  \
# 0     @lokalpendaki pilihlah pemimpin yang menolak r...
# 1     terima kasih yb rafizi atas penjelasan. memang...
# 2     pandangan saya mengenai pekerja asing:\n\n1) i...
# 3     dgr tu org2 terpaling kemanusiaan.\n\nkorg byr...
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# Ambil stopwords dalam bahasa Indonesia (atau sesuai kebutuhan)
stop_words = set(stopwords.words('indonesian'))
stop_words.remove('tidak')

# Proses filtering tanpa menghapus kata "tidak"
def remove_stopwords(text):
  return [word for word in text if word not in stop_words]

df['Filtering'] = df['Tokenization'].apply(lambda x: remove_stopwords(x))
df.head(15000)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                 Content  \
# 0     @LokalPendaki pilihlah pemimpin yang menolak r...
# 1     Terima kasih yb rafizi atas penjelasan. Memang...
# 2     Pandangan saya mengenai pekerja asing:\n\n1) I...
# 3     Dgr tu org2 terpaling kemanusiaan.\n\nKorg byr...
# 4     suka cara doktor ni cakap tentang pendatang as...
# ...                                                 ...
# 1040  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 1041  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 1042  @folkshittmedia Nanti kalau meninggal datang t...
# 1043  @Bossbm17 @mynewshub Utk kerja Di kilang tidak...
# 1044  @kimtuwits @MALAYSIAVIRALLL dua pukimak. 1 tak...
#
#                                            Case Folding  \
# 0     @lokalpendaki pilihlah pemimpin yang menolak r...
# ...

# %%
#Steamming Data

# !pip install Sastrawi

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_text(text):
  return [stemmer.stem(word) for word in text]

df['Stemming'] = df['Filtering'].apply(lambda x: ' '.join(stem_text(x)))
df.head(15000)
# Out:
# ...
#                                                 Content  \
# 0     @LokalPendaki pilihlah pemimpin yang menolak r...
# 1     Terima kasih yb rafizi atas penjelasan. Memang...
# 2     Pandangan saya mengenai pekerja asing:\n\n1) I...
# 3     Dgr tu org2 terpaling kemanusiaan.\n\nKorg byr...
# 4     suka cara doktor ni cakap tentang pendatang as...
# ...                                                 ...
# 1040  @kegblgnunfaedh Jejak digital ini tak bisa hil...
# 1041  @tanyakanrl Twit2 Palestine sekarang sepi pemi...
# 1042  @folkshittmedia Nanti kalau meninggal datang t...
# 1043  @Bossbm17 @mynewshub Utk kerja Di kilang tidak...
# 1044  @kimtuwits @MALAYSIAVIRALLL dua pukimak. 1 tak...
#
#                                            Case Folding  \
# 0     @lokalpendaki pilihlah pemimpin yang menolak r...
# 1     terima kasih yb rafizi atas penjelasan. memang...
# 2     pandangan saya mengenai pekerja asing:\n\n1) i...
# 3     dgr tu org2 terpaling kemanusiaan.\n\nkorg byr...
# ...

# %%
# Simpan ke file CSV
df.to_csv('Rohingya Clean.csv', encoding='utf8', index=False)
